# %%
import pandas as pd

# %%
df = pd.read_csv('/content/movie_dataset.csv')

# %%
print(df.shape)
# Out:
# (4803, 24)

# %%
print(df.dtypes)
# Out:
# index                     int64
# budget                    int64
# genres                   object
# homepage                 object
# id                        int64
# keywords                 object
# original_language        object
# original_title           object
# overview                 object
# popularity              float64
# production_companies     object
# production_countries     object
# release_date             object
# revenue                   int64
# runtime                 float64
# spoken_languages         object
# status                   object
# tagline                  object
# title                    object
# vote_average            float64
# vote_count                int64
# cast                     object
# crew                     object
# director                 object
# dtype: object

# %%
df.head()
# Out:
#    index     budget                                    genres  \
# 0      0  237000000  Action Adventure Fantasy Science Fiction
# 1      1  300000000                  Adventure Fantasy Action
# 2      2  245000000                    Action Adventure Crime
# 3      3  250000000               Action Crime Drama Thriller
# 4      4  260000000          Action Adventure Science Fiction
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  culture clash future space war space colony so...                en
# 1  ocean drug abuse exotic island east india trad...                en
# ...

# %%
print(df.isnull().sum())
# Out:
# index                      0
# budget                     0
# genres                    28
# homepage                3091
# id                         0
# keywords                 412
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    2
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# cast                      43
# crew                       0
# director                  30
# dtype: int64

# %% [markdown]
# Handling text data (converting to lowercase)

# %% [markdown]
# Text PreProcessing

# %%
df['tagline'] = df['tagline'].str.lower()

# %% [markdown]
#  Handling text data (removing punctuation)

# %%
import string
df['tagline'] = df['tagline'].str.translate(
str.maketrans('', '', string.punctuation))

# %% [markdown]
# Handling text data (removing stop words)

# %%
df.head()
# Out:
#    index     budget                                    genres  \
# 0      0  237000000  Action Adventure Fantasy Science Fiction
# 1      1  300000000                  Adventure Fantasy Action
# 2      2  245000000                    Action Adventure Crime
# 3      3  250000000               Action Crime Drama Thriller
# 4      4  260000000          Action Adventure Science Fiction
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  culture clash future space war space colony so...                en
# 1  ocean drug abuse exotic island east india trad...                en
# ...

# %% [markdown]
#  Stop words are common words like very, some,
# between etc. To save up the space and speed up the process of prediction, these stop words needs to be removed using NLTK
# corpus.

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords

# %%
stop_words=set(stopwords.words('english'))

# %%
df.head()
# Out:
#    index     budget                                    genres  \
# 0      0  237000000  Action Adventure Fantasy Science Fiction
# 1      1  300000000                  Adventure Fantasy Action
# 2      2  245000000                    Action Adventure Crime
# 3      3  250000000               Action Crime Drama Thriller
# 4      4  260000000          Action Adventure Science Fiction
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  culture clash future space war space colony so...                en
# 1  ocean drug abuse exotic island east india trad...                en
# ...

# %%
def remove_stopwords(tagline):
  return " ".join([word for word in str(tagline).split() if word not in stop_words])
df['tagline']= df['tagline'].apply(lambda x: remove_stopwords(x))

# %%
df['tagline'].value_counts()
# Out:
# nan                                   844
# based true story                        5
# way                                     4
# game                                    4
# careful wish                            3
#                                      ...
# fight save world                        1
# music passion survival masterpiece      1
# child would change world                1
# prey slay display                       1
# new yorker shanghai                     1
# Name: tagline, Length: 3898, dtype: int64

# %%
from nltk.stem import WordNetLemmatizer

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %% [markdown]
# lemmatization: is a text pre-processing technique used in natural language processing (NLP) models to break a word down to its root meaning to identify similarities. For example, a lemmatization algorithm would reduce the word better to its root word, or lemme, good.

# %%
lemmatizer = WordNetLemmatizer()
def lemmatize_words(tagline):
  return" ".join([lemmatizer.lemmatize(word) for word in tagline.split()])
df['tagline'] = df['tagline'].apply(lambda tagline: lemmatize_words(tagline))

# %%
df.tail()
# Out:
#       index  budget                         genres  \
# 4798   4798  220000          Action Crime Thriller
# 4799   4799    9000                 Comedy Romance
# 4800   4800       0  Comedy Drama Romance TV Movie
# 4801   4801       0                            NaN
# 4802   4802       0                    Documentary
#
#                                                homepage      id  \
# 4798                                                NaN    9367
# 4799                                                NaN   72766
# 4800  http://www.hallmarkchannel.com/signedsealeddel...  231617
# 4801                        http://shanghaicalling.com/  126186
# 4802                                                NaN   25975
#
#                                                keywords original_language  \
# 4798  united states\u2013mexico barrier legs arms pa...                es
# 4799                                                NaN                en
# ...

# %%
#vote_average

# %% [markdown]
# Chaning the data type of column from float to integer

# %%
df['vote_average'] = df['vote_average'].astype('int64')

# %%
print(df['vote_average'])
# Out:
# 0       7
# 1       6
# 2       6
# 3       7
# 4       6
#        ..
# 4798    6
# 4799    5
# 4800    7
# 4801    5
# 4802    6
# Name: vote_average, Length: 4803, dtype: int64

# %% [markdown]
# Splitting the votes in categories based on vote average from 'superhit' to 'very bad'

# %%
df['vote_average']= pd.cut(df['vote_average'],bins=5,labels=['Superhit','hit','good','bad','very bad'])

# %%
df
# Out:
#       index     budget                                    genres  \
# 0         0  237000000  Action Adventure Fantasy Science Fiction
# 1         1  300000000                  Adventure Fantasy Action
# 2         2  245000000                    Action Adventure Crime
# 3         3  250000000               Action Crime Drama Thriller
# 4         4  260000000          Action Adventure Science Fiction
# ...     ...        ...                                       ...
# 4798   4798     220000                     Action Crime Thriller
# 4799   4799       9000                            Comedy Romance
# 4800   4800          0             Comedy Drama Romance TV Movie
# 4801   4801          0                                       NaN
# 4802   4802          0                               Documentary
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
df['vote_average'].value_counts()
# Out:
# good        3287
# bad          982
# hit          440
# Superhit      88
# very bad       6
# Name: vote_average, dtype: int64

# %%
print(df['release_date'])
# Out:
# 0       2009-12-10
# 1       2007-05-19
# 2       2015-10-26
# 3       2012-07-16
# 4       2012-03-07
#            ...
# 4798    1992-09-04
# 4799    2011-12-26
# 4800    2013-10-13
# 4801    2012-05-03
# 4802    2005-08-05
# Name: release_date, Length: 4803, dtype: object

# %%
df['release_date']=pd.to_datetime(df['release_date'])

# %% [markdown]
# Extracting year, month and day

# %%
df['year'] = df['release_date'].dt.year
df['month'] = df['release_date'].dt.month
df['day'] = df['release_date'].dt.day

# %%
df['year'].value_counts()
# Out:
# 2009.0    247
# 2014.0    238
# 2006.0    237
# 2013.0    231
# 2008.0    227
#          ...
# 1935.0      1
# 1932.0      1
# 1916.0      1
# 1934.0      1
# 1925.0      1
# Name: year, Length: 90, dtype: int64
